# %%
import os

os.listdir()
# Out:
# ['.AltairRapidMiner',
#  '.aws',
#  '.azure',
#  '.cagent',
#  '.config',
#  '.docker',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.ms-ad',
#  '.python_history',
#  'Ambiente de Impressão',
#  'Ambiente de Rede',
#  'AppData',
#  'Configurações Locais',
#  'Contacts',
#  'Cookies',
#  'Dados de Aplicativos',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'hospital_analysis.ipynb',
#  'hospital_readmission_dataset.csv',
#  'Links',
#  'Menu Iniciar',
#  'Meus Documentos',
#  'Modelos',
#  'Music',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{fb77b95e-aa38-11ef-ab7a-d09466e126c9}.TM.blf',
#  'NTUSER.DAT{fb77b95e-aa38-11ef-ab7a-d09466e126c9}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{fb77b95e-aa38-11ef-ab7a-d09466e126c9}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Videos']

# %%
import pandas as pd

df = pd.read_csv('hospital_readmission_dataset.csv')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   patient_id                 8000 non-null   str
#  1   admission_date             8000 non-null   str
#  2   season                     8000 non-null   str
#  3   age                        8000 non-null   int64
#  4   gender                     8000 non-null   str
#  5   region                     8000 non-null   str
#  6   primary_diagnosis          8000 non-null   str
#  7   comorbidities_count        8000 non-null   int64
#  8   length_of_stay             8000 non-null   int64
#  9   treatment_type             8000 non-null   str
#  10  medications_count          8000 non-null   int64
#  11  followup_visits_last_year  8000 non-null   int64
#  12  prev_readmissions          8000 non-null   int64
#  13  insurance_type             8000 non-null   str
# ...

# %%
df.describe()
# Out:
#                age  comorbidities_count  length_of_stay  medications_count  \
# count  8000.000000          8000.000000     8000.000000        8000.000000
# mean     57.411625             4.318500        7.789125           7.475750
# std      16.724388             1.358046        1.930252           2.287917
# min      18.000000             1.000000        3.000000           2.000000
# 25%      46.000000             3.000000        6.000000           6.000000
# 50%      57.000000             4.000000        8.000000           8.000000
# 75%      69.000000             5.000000        9.000000           9.000000
# max      95.000000            10.000000       15.000000          18.000000
#
#        followup_visits_last_year  prev_readmissions  readmission_risk_score  \
# count                8000.000000         8000.00000             8000.000000
# mean                    3.638125            1.57250                0.776937
# ...

# %%
df['primary_diagnosis'].value_counts()
# Out:
# primary_diagnosis
# Diabetes          1470
# Hypertension      1301
# COPD               952
# Stroke             883
# Kidney Disease     868
# Appendicitis       534
# Sepsis             497
# Fracture           434
# Pneumonia          425
# Heart Failure      403
# Influenza          233
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['primary_diagnosis'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Diagnósticos Mais Frequentes')
plt.xlabel('Diagnóstico')
plt.ylabel('Quantidade de Pacientes')
plt.xticks(rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt

df['primary_diagnosis'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Diagnósticos Mais Frequentes')
plt.xlabel('Diagnóstico')
plt.ylabel('Quantidade de Pacientes')
plt.xticks(rotation=45)

plt.savefig('top_diagnosticos.png', bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt

df['primary_diagnosis'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Diagnósticos Mais Frequentes')
plt.xlabel('Diagnóstico')
plt.ylabel('Quantidade de Pacientes')
plt.xticks(rotation=45)

plt.savefig('top_diagnosticos.png', bbox_inches='tight')

plt.show()
